# %% [markdown]
# #

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 



# Creating the enriched dataset
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank', 'Grace', 'Helen', 'Ivy', 'Jack',
             'Alice', 'Eva', 'Charlie', 'Eva'],  # Duplicate names
    'Age': [25, 30, 35, np.nan, 40, 50, -999, 28, None, 45, 25, 30, 35, 40],  # Missing values, None, Outlier (-999)
    'Gender': ['Female', 'Male', 'male', 'Female', 'Female', np.nan, 'Female', 'f', 'Female', 'Male',
               'Female', 'Female', 'Male', 'Female'],  # Inconsistent capitalization
    'Math_Score': [88, 92, 100, 78, 85, np.nan, 110, 95, 60, 88, 88, np.nan, 'N/A', 85],  # Missing values, Outliers, Incorrect data type
    'Science_Score': [np.nan, 85, 95, 70, 'missing', 98, 100, 105, 60, 77, 85, 85, 70, 70],  # Missing values, Inconsistent data representation
    'Enrollment_Date': ['2020-01-15', '15/02/2020', '2020/03/10', 'April 5, 2020', np.nan, '2020-05-25',
                        '2020-06-30', 'July 10, 2020', '2020-08-15', '2020-09-01', '2020-01-15', '2020-05-25',
                        '2020/03/10', 'April 5, 2020'],  # Inconsistent date formats, Missing values
    'Graduated': ['Yes', 'No', 'No', 'Yes', 'No', np.nan, 'yes', 'No', 'Yes', 'no', 'Yes', 'No', 'No', 'Yes'],  # Inconsistent capitalization
}

# Converting into a DataFrame
df = pd.DataFrame(data)
df
# Out:
#        Name    Age  Gender Math_Score Science_Score Enrollment_Date Graduated
# 0     Alice   25.0  Female         88           NaN      2020-01-15       Yes
# 1       Bob   30.0    Male         92            85      15/02/2020        No
# 2   Charlie   35.0    male        100            95      2020/03/10        No
# 3     David    NaN  Female         78            70   April 5, 2020       Yes
# 4       Eva   40.0  Female         85       missing             NaN        No
# 5     Frank   50.0     NaN        NaN            98      2020-05-25       NaN
# 6     Grace -999.0  Female        110           100      2020-06-30       yes
# 7     Helen   28.0       f         95           105   July 10, 2020        No
# 8       Ivy    NaN  Female         60            60      2020-08-15       Yes
# 9      Jack   45.0    Male         88            77      2020-09-01        no
# 10    Alice   25.0  Female         88            85      2020-01-15       Yes
# ...

# %%
## Duplicated Entries

# %%
 duplicates = df.duplicated()

# %%
duplicates
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# dtype: bool

# %%
## Removing Duplicates

# %%
 remove = df_cleaned = df.drop_duplicates()

# %%
remove
# Out:
#        Name    Age  Gender Math_Score Science_Score Enrollment_Date Graduated
# 0     Alice   25.0  Female         88           NaN      2020-01-15       Yes
# 1       Bob   30.0    Male         92            85      15/02/2020        No
# 2   Charlie   35.0    male        100            95      2020/03/10        No
# 3     David    NaN    Male         78            70   April 5, 2020       Yes
# 4       Eva   40.0  Female         85       missing             NaN        No
# 5     Frank   50.0    Male        NaN            98      2020-05-25       NaN
# 6     Grace -999.0  Female        110           100      2020-06-30       yes
# 7     Helen   28.0       f         95           105   July 10, 2020        No
# 8       Ivy    NaN  Female         60            60      2020-08-15       Yes
# 9      Jack   45.0    Male         88            77      2020-09-01        no
# 10    Alice   25.0  Female         88            85      2020-01-15       Yes
# ...

# %%
## Handling Missing Values

# %%
Missing_Values = df.isnull()

# %%
Missing_Values
# Out:
#      Name    Age  Gender  Math_Score  Science_Score  Enrollment_Date  \
# 0   False  False   False       False           True            False
# 1   False  False   False       False          False            False
# 2   False  False   False       False          False            False
# 3   False   True   False       False          False            False
# 4   False  False   False       False          False             True
# 5   False  False   False        True          False            False
# 6   False  False   False       False          False            False
# 7   False  False   False       False          False            False
# 8   False   True   False       False          False            False
# 9   False  False   False       False          False            False
# 10  False  False   False       False          False            False
# 11  False  False   False        True          False            False
# 12  False  False   False       False          False            False
# ...

# %%
Sum_MValues = df.isnull().sum()

# %%
Sum_MValues
# Out:
# Name               0
# Age                2
# Gender             0
# Math_Score         2
# Science_Score      1
# Enrollment_Date    1
# Graduated          1
# dtype: int64

# %%
total_missing = df.isnull().sum().sum()

# %%
total_missing
# Out:
# np.int64(7)

# %%
 rows_with_missing = df[df.isnull().any(axis=1)]

# %%
rows_with_missing
# Out:
#      Name   Age  Gender Math_Score Science_Score Enrollment_Date Graduated
# 0   Alice  25.0  Female         88           NaN      2020-01-15       Yes
# 3   David   NaN    Male         78            70   April 5, 2020       Yes
# 4     Eva  40.0  Female         85       missing             NaN        No
# 5   Frank  50.0    Male        NaN            98      2020-05-25       NaN
# 8     Ivy   NaN  Female         60            60      2020-08-15       Yes
# 11    Eva  30.0  Female        NaN            85      2020-05-25        No

# %%
 df['Name'] = df['Name'].str.strip()

# %%
df['Name']
# Out:
# 0       Alice
# 1         Bob
# 2     Charlie
# 3       David
# 4         Eva
# 5       Frank
# 6       Grace
# 7       Helen
# 8         Ivy
# 9        Jack
# 10      Alice
# 11        Eva
# 12    Charlie
# 13        Eva
# Name: Name, dtype: object

# %%
df.dtypes
# Out:
# Name                object
# Age                float64
# Gender              object
# Math_Score          object
# Science_Score       object
# Enrollment_Date     object
# Graduated           object
# dtype: object

# %%
pd.set_option('future.no_silent_downcasting', True)
df["Math_Score"] = df["Math_Score"].replace("N/A", np.nan).astype(float)

# %%
df["Math_Score"]
# Out:
# 0      88.0
# 1      92.0
# 2     100.0
# 3      78.0
# 4      85.0
# 5       NaN
# 6     110.0
# 7      95.0
# 8      60.0
# 9      88.0
# 10     88.0
# 11      NaN
# 12      NaN
# 13     85.0
# Name: Math_Score, dtype: float64

# %%
df.loc[:, "Science_Score"] = df["Science_Score"].replace("missing", np.nan).astype(float)

# %%
df['Science_Score']
# Out:
# 0       NaN
# 1      85.0
# 2      95.0
# 3      70.0
# 4       NaN
# 5      98.0
# 6     100.0
# 7     105.0
# 8      60.0
# 9      77.0
# 10     85.0
# 11     85.0
# 12     70.0
# 13     70.0
# Name: Science_Score, dtype: object

# %%
df
# Out:
#        Name    Age  Gender  Math_Score Science_Score Enrollment_Date Graduated
# 0     Alice   25.0  Female        88.0           NaN      2020-01-15       Yes
# 1       Bob   30.0    Male        92.0          85.0      15/02/2020        No
# 2   Charlie   35.0    male       100.0          95.0      2020/03/10        No
# 3     David    NaN    Male        78.0          70.0   April 5, 2020       Yes
# 4       Eva   40.0  Female        85.0           NaN             NaN        No
# 5     Frank   50.0    Male         NaN          98.0      2020-05-25       NaN
# 6     Grace -999.0  Female       110.0         100.0      2020-06-30       yes
# 7     Helen   28.0       f        95.0         105.0   July 10, 2020        No
# 8       Ivy    NaN  Female        60.0          60.0      2020-08-15       Yes
# 9      Jack   45.0    Male        88.0          77.0      2020-09-01        no
# 10    Alice   25.0  Female        88.0          85.0      2020-01-15       Yes
# ...

# %%
df['Gender'] = df['Gender'].replace({
 "male": "Male",
    "f": "Female"
})

# %%
df
# Out:
#        Name    Age  Gender  Math_Score Science_Score Enrollment_Date Graduated
# 0     Alice   25.0  Female        88.0           NaN      2020-01-15       Yes
# 1       Bob   30.0    Male        92.0          85.0      15/02/2020        No
# 2   Charlie   35.0    Male       100.0          95.0      2020/03/10        No
# 3     David    NaN    Male        78.0          70.0   April 5, 2020       Yes
# 4       Eva   40.0  Female        85.0           NaN             NaN        No
# 5     Frank   50.0    Male         NaN          98.0      2020-05-25       NaN
# 6     Grace -999.0  Female       110.0         100.0      2020-06-30       yes
# 7     Helen   28.0  Female        95.0         105.0   July 10, 2020        No
# 8       Ivy    NaN  Female        60.0          60.0      2020-08-15       Yes
# 9      Jack   45.0    Male        88.0          77.0      2020-09-01        no
# 10    Alice   25.0  Female        88.0          85.0      2020-01-15       Yes
# ...

# %%
df['Enrollment_Date'] = df['Enrollment_Date'].replace({
 "15/02/2020": "2020-02-15",
    "2020/03/10": "2020-03-10",
    "April 5, 2020": "2020-04-05",
    "July 10, 2020": "2020-07-10",
    "April 5, 2020": "2020-04-05"

})

# %%
df
# Out:
#        Name    Age  Gender  Math_Score Science_Score Enrollment_Date Graduated
# 0     Alice   25.0  Female        88.0           NaN      2020-01-15       Yes
# 1       Bob   30.0    Male        92.0          85.0      2020-02-15        No
# 2   Charlie   35.0    Male       100.0          95.0      2020-03-10        No
# 3     David    NaN    Male        78.0          70.0      2020-04-05       Yes
# 4       Eva   40.0  Female        85.0           NaN             NaN        No
# 5     Frank   50.0    Male         NaN          98.0      2020-05-25       NaN
# 6     Grace -999.0  Female       110.0         100.0      2020-06-30       yes
# 7     Helen   28.0  Female        95.0         105.0      2020-07-10        No
# 8       Ivy    NaN  Female        60.0          60.0      2020-08-15       Yes
# 9      Jack   45.0    Male        88.0          77.0      2020-09-01        no
# 10    Alice   25.0  Female        88.0          85.0      2020-01-15       Yes
# ...

# %%
df['Graduated'] = df['Graduated'].replace({
 "yes": "Yes",
    "no": "No"

})

# %%
df
# Out:
#        Name    Age  Gender  Math_Score Science_Score Enrollment_Date Graduated
# 0     Alice   25.0  Female        88.0           NaN      2020-01-15       Yes
# 1       Bob   30.0    Male        92.0          85.0      2020-02-15        No
# 2   Charlie   35.0    Male       100.0          95.0      2020-03-10        No
# 3     David    NaN    Male        78.0          70.0      2020-04-05       Yes
# 4       Eva   40.0  Female        85.0           NaN             NaN        No
# 5     Frank   50.0    Male         NaN          98.0      2020-05-25       NaN
# 6     Grace -999.0  Female       110.0         100.0      2020-06-30       Yes
# 7     Helen   28.0  Female        95.0         105.0      2020-07-10        No
# 8       Ivy    NaN  Female        60.0          60.0      2020-08-15       Yes
# 9      Jack   45.0    Male        88.0          77.0      2020-09-01        No
# 10    Alice   25.0  Female        88.0          85.0      2020-01-15       Yes
# ...

# %%
df['Age'] = df['Age'].replace({
 "NaN": 35.0,
    

})

# %%
df
# Out:
#        Name    Age  Gender  Math_Score Science_Score Enrollment_Date Graduated
# 0     Alice   25.0  Female        88.0           NaN      2020-01-15       Yes
# 1       Bob   30.0    Male        92.0          85.0      2020-02-15        No
# 2   Charlie   35.0    Male       100.0          95.0      2020-03-10        No
# 3     David    NaN    Male        78.0          70.0      2020-04-05       Yes
# 4       Eva   40.0  Female        85.0           NaN             NaN        No
# 5     Frank   50.0    Male         NaN          98.0      2020-05-25       NaN
# 6     Grace -999.0  Female       110.0         100.0      2020-06-30       Yes
# 7     Helen   28.0  Female        95.0         105.0      2020-07-10        No
# 8       Ivy    NaN  Female        60.0          60.0      2020-08-15       Yes
# 9      Jack   45.0    Male        88.0          77.0      2020-09-01        No
# 10    Alice   25.0  Female        88.0          85.0      2020-01-15       Yes
# ...

# %%
df["Age"].dtype
# Out:
# dtype('float64')

# %%
df.loc[8, "Age"] = 35.0

# %%
df
# Out:
#        Name    Age  Gender  Math_Score Science_Score Enrollment_Date Graduated
# 0     Alice   25.0  Female        88.0           NaN      2020-01-15       Yes
# 1       Bob   30.0    Male        92.0          85.0      2020-02-15        No
# 2   Charlie   35.0    Male       100.0          95.0      2020-03-10        No
# 3     David    NaN    Male        78.0          70.0      2020-04-05       Yes
# 4       Eva   40.0  Female        85.0           NaN             NaN        No
# 5     Frank   50.0    Male         NaN          98.0      2020-05-25       NaN
# 6     Grace -999.0  Female       110.0         100.0      2020-06-30       Yes
# 7     Helen   28.0  Female        95.0         105.0      2020-07-10        No
# 8       Ivy   35.0  Female        60.0          60.0      2020-08-15       Yes
# 9      Jack   45.0    Male        88.0          77.0      2020-09-01        No
# 10    Alice   25.0  Female        88.0          85.0      2020-01-15       Yes
# ...

# %%
df.loc[6, "Age"] = 35.0
df.loc[3, "Age"] = 35.0
df
# Out:
#        Name   Age  Gender  Math_Score Science_Score Enrollment_Date Graduated
# 0     Alice  25.0  Female        88.0           NaN      2020-01-15       Yes
# 1       Bob  30.0    Male        92.0          85.0      2020-02-15        No
# 2   Charlie  35.0    Male       100.0          95.0      2020-03-10        No
# 3     David  35.0    Male        78.0          70.0      2020-04-05       Yes
# 4       Eva  40.0  Female        85.0           NaN             NaN        No
# 5     Frank  50.0    Male         NaN          98.0      2020-05-25       NaN
# 6     Grace  35.0  Female       110.0         100.0      2020-06-30       Yes
# 7     Helen  28.0  Female        95.0         105.0      2020-07-10        No
# 8       Ivy  35.0  Female        60.0          60.0      2020-08-15       Yes
# 9      Jack  45.0    Male        88.0          77.0      2020-09-01        No
# 10    Alice  25.0  Female        88.0          85.0      2020-01-15       Yes
# ...

# %%
combined_df = (
    df.groupby('Name', group_keys=False)  
      .apply(lambda group: group.iloc[:, 1:].ffill().bfill().iloc[0])  
)

combined_df.insert(0, 'Name', combined_df.index)


combined_df = combined_df.reset_index(drop=True)

print(combined_df)
# Out:
#       Name   Age  Gender  Math_Score  Science_Score Enrollment_Date Graduated
# 0    Alice  25.0  Female        88.0           85.0      2020-01-15       Yes
# 1      Bob  30.0    Male        92.0           85.0      2020-02-15        No
# 2  Charlie  35.0    Male       100.0           95.0      2020-03-10        No
# 3    David  35.0    Male        78.0           70.0      2020-04-05       Yes
# 4      Eva  40.0  Female        85.0           85.0      2020-05-25        No
# 5    Frank  50.0    Male         NaN           98.0      2020-05-25       NaN
# 6    Grace  35.0  Female       110.0          100.0      2020-06-30       Yes
# 7    Helen  28.0  Female        95.0          105.0      2020-07-10        No
# 8      Ivy  35.0  Female        60.0           60.0      2020-08-15       Yes
# 9     Jack  45.0    Male        88.0           77.0      2020-09-01        No
# ...

# %%
combined_df
# Out:
#       Name   Age  Gender  Math_Score  Science_Score Enrollment_Date Graduated
# 0    Alice  25.0  Female        88.0           85.0      2020-01-15       Yes
# 1      Bob  30.0    Male        92.0           85.0      2020-02-15        No
# 2  Charlie  35.0    Male       100.0           95.0      2020-03-10        No
# 3    David  35.0    Male        78.0           70.0      2020-04-05       Yes
# 4      Eva  40.0  Female        85.0           85.0      2020-05-25        No
# 5    Frank  50.0    Male         NaN           98.0      2020-05-25       NaN
# 6    Grace  35.0  Female       110.0          100.0      2020-06-30       Yes
# 7    Helen  28.0  Female        95.0          105.0      2020-07-10        No
# 8      Ivy  35.0  Female        60.0           60.0      2020-08-15       Yes
# 9     Jack  45.0    Male        88.0           77.0      2020-09-01        No

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Age'], bins=10, kde=True, color='skyblue') 
plt.title('Distribution of Age', fontsize=16)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
data = {"Gender": ["Male", "Female"], "Count": [3, 6]}
df = pd.DataFrame(data)
plt.pie(df["Count"], labels=df["Gender"], autopct="%1.1f%%")
plt.title("Gender Distribution")
plt.show()

# %%
df = pd.DataFrame({
    "Science_Score": [85,95,70,100,105,60,77,85,70],
    "Math_Score": [92,100,78,110,95,60,88,88,85]
 
})
plt.scatter(df.index, df["Math_Score"], color="blue", label="Math Score", s=100, alpha=0.7)
plt.scatter(df.index, df["Science_Score"], color="red", label="Science Score", s=100, alpha=0.7)

plt.xlabel("Index")
plt.ylabel("Score")
plt.title("Scatter Plot of Math_Score and Science_Score")
plt.legend() 
plt.show()

# %%
combined_df['Enrollment_Date'] = pd.to_datetime(combined_df['Enrollment_Date'])

# %%
combined_df
# Out:
#       Name   Age  Gender  Math_Score  Science_Score Enrollment_Date Graduated
# 0    Alice  25.0  Female        88.0           85.0      2020-01-15       Yes
# 1      Bob  30.0    Male        92.0           85.0      2020-02-15        No
# 2  Charlie  35.0    Male       100.0           95.0      2020-03-10        No
# 3    David  35.0    Male        78.0           70.0      2020-04-05       Yes
# 4      Eva  40.0  Female        85.0           85.0      2020-05-25        No
# 5    Frank  50.0    Male         NaN           98.0      2020-05-25       NaN
# 6    Grace  35.0  Female       110.0          100.0      2020-06-30       Yes
# 7    Helen  28.0  Female        95.0          105.0      2020-07-10        No
# 8      Ivy  35.0  Female        60.0           60.0      2020-08-15       Yes
# 9     Jack  45.0    Male        88.0           77.0      2020-09-01        No

# %%
plt.figure(figsize=(10, 6))
plt.hist(combined_df['Enrollment_Date'], bins=10, edgecolor='black')

plt.title('Distribution of Enrollment Dates')
plt.xlabel('Enrollment Date')
plt.ylabel('Number of Students')

plt.xticks(rotation=45)  
plt.tight_layout()
plt.show()

# %%
sns.pairplot(combined_df)
plt.suptitle('Pair Plot: Relationships Between Age, Math_Score, and Science_Score', y=1.02)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='Gender', y='Math_Score', data=combined_df)
plt.title('Violin Plot of Math Scores by Gender')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='Gender', y='Science_Score', data=combined_df)
plt.title('Violin Plot of Science Scores by Gender')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Graduated', y='Math_Score', data=combined_df)
plt.title('Box Plot of Math Scores by Graduation Status')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.boxplot(x='Graduated', y='Science_Score', data=combined_df)
plt.title('Box Plot of Math Scores by Graduation Status')
plt.show()

# %%
plt.figure(figsize=(7, 3))
sns.kdeplot(combined_df['Math_Score'], color="Black", label="Math Score")
plt.title('KDE Plot of Math Scores')
plt.xlabel('Score')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(7, 3))
sns.kdeplot(combined_df['Science_Score'], color="Blue", label="Science Score")
plt.title('KDE Plot of Science Scores')
plt.xlabel('Score')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.kdeplot(combined_df['Math_Score'], fill=True, color="Orange", label="Math Score")
plt.title('KDE Plot of Math Scores')
plt.xlabel('Score')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.kdeplot(combined_df['Science_Score'], fill=True, color="Black", label="Science Score")
plt.title('KDE Plot of Science Scores')
plt.xlabel('Score')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 8))

columns = ['Age', 'Math_Score', 'Science_Score']
for i, column in enumerate(columns, 1):
    plt.subplot(2, 2, i)
    sns.histplot(combined_df[column], kde=True, bins=10, color='blue')  
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x='Graduated', y='Math_Score', data=combined_df, hue='Graduated', palette='Set2', legend=False)
plt.title('Comparison of Math Scores by Graduation Status')
plt.xlabel('Graduation Status')
plt.ylabel('Math Score')
plt.show()
##The one who is graduated have the result ranges from 60- 110 whereas the one who was not graduated ranges from 80-100. It seems that both scored good but some of them could not be graduated. So, it seems that Math score do not have any relation with the status of the students' graduation and there must be some other factors that led to the difference in their graduation status

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Age', y='Math_Score', data=combined_df, color='Green', marker='o')
plt.title('Scatter Plot: Age vs Math Score')
plt.xlabel('Age')
plt.ylabel('Math Score')
plt.show()
## As you can see from the chart here, the highest and the lowest score is registered for the student whose age is 35. Students whose age is more than 35 has shown a little bit lesser result but the difference is not that significant.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Age', y='Enrollment_Date', data=combined_df, color='green', marker='o')
plt.title('Scatter Plot: Age vs Enrollment Date')
plt.xlabel('Age')
plt.ylabel('Enrollment Date')
plt.show()
## the youngest student registered early before February. Students above 40 registered late after June. However, I couldn't see strong correlation between age and enrollment dates.
